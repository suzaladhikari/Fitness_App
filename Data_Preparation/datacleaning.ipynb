# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### The first and the most important part of every data analytics project is to make sure that the data we are using has no null-values, and also checking if the data types are what we need. Doing such will help us in the building machine learning model and data analytics. We will be doing the data preparation in this notebook

# %%
### Data set we will be working and modifying on 
uncleanedData = pd.read_csv("../Datasets/raw_data.csv")
uncleanedData.head(5)
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.91    Male        65.27        1.62   188.58   157.65        69.05
# 1  23.37  Female        56.41        1.55   179.43   131.75        73.18
# 2  33.20  Female        58.98        1.67   175.04   123.95        54.96
# 3  38.69  Female        93.78        1.70   191.21   155.10        50.07
# 4  45.09    Male        52.42        1.88   193.58   152.88        70.84
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  ...  \
# 0                      1.00          1080.90     Strength  ...
# 1                      1.37          1809.91         HIIT  ...
# 2                      0.91           802.26       Cardio  ...
# 3                      1.10          1450.79         HIIT  ...
# 4                      1.08          1166.40     Strength  ...
#
#    cal_from_macros  pct_carbs  protein_per_kg   pct_HRR  pct_maxHR  \
# 0          2139.59   0.500432        1.624789  0.741237   0.835985
# ...

# %%
## Lets see the physical properties of the data, the number of rows and columns and the datattypes
print(f"The data has {uncleanedData.shape[0]} number of rows and {uncleanedData.shape[1]} number of columns")
print("-------------------------------------")
print(f"The data types of the columns are :")
print(uncleanedData.info())
# Out:
# The data has 20000 number of rows and 54 number of columns
# -------------------------------------
# The data types of the columns are :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             20000 non-null  float64
#  1   Gender                          20000 non-null  object
#  2   Weight (kg)                     20000 non-null  float64
#  3   Height (m)                      20000 non-null  float64
#  4   Max_BPM                         20000 non-null  float64
#  5   Avg_BPM                         20000 non-null  float64
#  6   Resting_BPM                     20000 non-null  float64
#  7   Session_Duration (hours)        20000 non-null  float64
#  8   Calories_Burned                 20000 non-null  float64
# ...

# %% [markdown]
# ### As we can see all the data types are perfect. Let's now check if the null values are present in the data set

# %%
## Checking the null values present in the data set 
print(uncleanedData.isna().sum())
# Out:
# Age                               0
# Gender                            0
# Weight (kg)                       0
# Height (m)                        0
# Max_BPM                           0
# Avg_BPM                           0
# Resting_BPM                       0
# Session_Duration (hours)          0
# Calories_Burned                   0
# Workout_Type                      0
# Fat_Percentage                    0
# Water_Intake (liters)             0
# Workout_Frequency (days/week)     0
# Experience_Level                  0
# BMI                               0
# Daily meals frequency             0
# Physical exercise                 0
# Carbs                             0
# Proteins                          0
# Fats                              0
# Calories                          0
# meal_name                         0
# meal_type                         0
# diet_type                         0
# sugar_g                           0
# sodium_mg                         0
# ...

# %% [markdown]
# ### Since the data has no null values and perfect data types the data is ready to be analyzed !

# %%
uncleanedData.to_csv('../Datasets/for_analytics.csv', index = False)
